# %%
import math
import pandas as pd
from matplotlib.gridspec import GridSpec

from _2k_astar import Map_2k, astar, canonical_astar, path_is_canonical
from utils import SearchTreePQS, euclidian_distance, h_2k, make_path
from testing import simple_test
from visualisation import draw
from grid import Map, Node
from full_graph_algorithm import full_graph_astar, MapFullGraph

# %matplotlib inline

# %%
height = 15
width = 30
map_str = '''
. . . . . . . . . . . . . . . . . . . . . @ @ . . . . . . .  
. . . . . . . . . . . . . . . . . . . . . @ @ . . . . . . . 
. . . . . . . . . . . . . . . . . . . . . @ @ . . . . . . . 
. . . @ @ . . . . . . . . . . . . . . . . @ @ . . . . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . @ @ . . . . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . @ @ @ @ @ . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . @ @ @ @ @ . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . . . . . . . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . . . . . . . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . . . . . . . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . . . . . . . . . . 
. . . @ @ . . . . . . . . @ @ . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . @ @ . . . . . . . . . . . . . . . 
. . . . . . . . . . . . . @ @ . . . . . . . . . . . . . . .
. . . . . . . . . . . . . @ @ . . . . . . . . . . . . . . .
'''

test_map = Map()
test_map.read_from_string(map_str, width, height)
start = Node(1, 1)
goal = Node(13, 28)
draw(test_map, start, goal)

# %%
k = 3
stats = simple_test(Map_2k(k), astar, 6, h_2k, SearchTreePQS, k=k)
# Out:
# Path found! Length: 33.31370849898476. Nodes created: 392. Number of steps: 261. Correct: False. Runtime: 0.03703045845031738ms.

# %%
k = 3
stats = simple_test(Map_2k(k), canonical_astar, 6, h_2k, SearchTreePQS, k=k, w=1000)
print("Path is canonical:", path_is_canonical(test_map, stats[1], k))
# Out:
# Path found! Length: 33.31370849898477. Nodes created: 81. Number of steps: 52. Correct: False. Runtime: 0.0020394325256347656ms.
# Path is canonical: True

# %%
stats = simple_test(MapFullGraph(), full_graph_astar, 6, euclidian_distance, SearchTreePQS)
# Out:
# Path found! Length: 31.314385337088538. Nodes created: 8144. Number of steps: 253. Correct: False. Runtime: 1.7512409687042236ms.
